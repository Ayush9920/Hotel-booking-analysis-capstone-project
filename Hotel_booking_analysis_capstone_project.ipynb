# %% [markdown]
# # **Project Title:- Hotel Booking Analysis**

# %% [markdown]
# ## **Project Description**

# %% [markdown]
# ## **Business Context:-**

# %% [markdown]
# ### Have you ever wondered the ideal season of the year to reserve a hotel room? Alternatively, how long should I remain to get the greatest daily rate? What if you wanted to foretell whether a hotel would unreasonably frequently receive unusual requests? You can investigate those questions using the data from hotel reservations!
#
# ### This dataset contains booking details for a city hotel and a resort hotel, as well as details like the data when the booking was made, the duration of the stay, the no of adults, kids,babies, and the no of parking spaces that are available. The data is devoid of any information that may be used to identify a specific person.
#
# ### Explore and analyse the data to discover important factors that govern the bookings

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("classic")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
hotel_data = pd.read_csv('/content/drive/MyDrive/Almabetter/Hotel Bookings.csv')

# %%
hotel_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
hotel_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# # **This dataset contains several columns**

# %%
hotel_data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df = hotel_data.copy()

# %%
df.index
# Out:
# RangeIndex(start=0, stop=119390, step=1)

# %% [markdown]
# # **Data type of each column**

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# # **Determining whether any column has a null value.**

# %%
df.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# company                   112593
# agent                      16340
# country                      488
# children                       4
# reserved_room_type             0
# assigned_room_type             0
# booking_changes                0
# deposit_type                   0
# hotel                          0
# previous_cancellations         0
# dtype: int64

# %% [markdown]
# # **putting information in the appropriate null values**

# %%
df[['agent','company']] = df[['agent','company']].fillna(0.0)

# %%
df['country'].fillna(hotel_data.country.mode().to_string(), inplace=True)
df['children'].fillna(round(hotel_data.children.mean()), inplace=True)

# %%
df[['children','company','agent']] = df[['children','company','agent']].astype('int64')

# %%
df["country"].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 178, dtype: int64

# %% [markdown]
# # **Which country has the most travellers?(Top 10)**

# %%
df["country"].value_counts()[:10]
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# ITA     3766
# IRL     3375
# BEL     2342
# BRA     2224
# NLD     2104
# Name: country, dtype: int64

# %% [markdown]
# # **Average number of nights stays.**

# %%
df['all_night']= df.apply(lambda x: x['stays_in_weekend_nights'] + x['stays_in_week_nights'], axis=1)
mean_night = df['all_night'].mean()
np.round(mean_night,2)
# Out:
# 3.43

# %% [markdown]
# # **Repeated guest count.**

# %%
df["is_repeated_guest"].value_counts()
# Out:
# 0    115580
# 1      3810
# Name: is_repeated_guest, dtype: int64

# %% [markdown]
# # **Creating a function to calculate a count.**

# %%
def calc_count(series, limit=None):
  if limit !=None:
      series = series.value_counts()[:limit]
  else:
      series = series.value_counts()
  x = series.index
  y = series/series.sum()*100
  return x.values,y.values

# %%
df["kids"] = df["children"] + df["babies"]

# %%
df_not_canceled = df[df["is_canceled"]==0]

# %%
#How many reservations were cancelled:
total_cancelled_reservations = df["is_canceled"].value_counts()
print(f"Total number of cancelled reservations is:{total_cancelled_reservations[0]}")
# Out:
# Total number of cancelled reservations is:75166

# %% [markdown]
# # **Data analysis of Hotel booking info.**

# %%
sns.countplot(x="reserved_room_type",data=df)
plt.legend(loc ="upper right")
plt.show
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # **Co-relation between all columns with numerical values.**

# %%
df["num_customers"] = df.apply(lambda x: x['adults'] + x['children'] + x['babies'], axis=1)
df["num_customers"].value_counts()
# Out:
# 2     82051
# 1     22581
# 3     10495
# 4      3929
# 0       180
# 5       137
# 26        5
# 12        2
# 27        2
# 20        2
# 10        2
# 40        1
# 50        1
# 55        1
# 6         1
# Name: num_customers, dtype: int64

# %%
num_df_subdata = df[['lead_time','previous_cancellations','previous_bookings_not_canceled','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces']]

# %%
corrmat = num_df_subdata.corr()
f, ax = plt.subplots(figsize=(9,7))
sns.heatmap(corrmat,annot = True,fmt='.2f', annot_kws={'size': 12},  vmax=.9, square=True);

# %% [markdown]
# # **Booking ratio between Resort hotel and city hotel**

# %%
hotel_type,pct_hotel_type = calc_count(df_not_canceled['hotel'])
sns.barplot(x=hotel_type,y=pct_hotel_type)
plt.title("The booking ratio between Resort Hotel and City Hotel")
plt.xlabel("Type of hotels")
plt.ylabel("Percent of booking")
plt.show()

# %%
hotel_type,pct_hotel_type
# Out:
# (array(['City Hotel', 'Resort Hotel'], dtype=object),
#  array([61.50121065, 38.49878935]))

# %% [markdown]
# #### From the above analysis:

# %% [markdown]
# The percentage of booking in City hotel is above 61.5%.
#
# The percentage of booking in Resort hotel is 38.5%.

# %%
groupby_hotel = df.groupby("hotel")
avg_adr = groupby_hotel["adr"].agg(np.mean).reset_index().rename(columns = {"adr":"avg_adr"})
plt.figure(figsize = (8,5))
sns.barplot(x= avg_adr["hotel"],y = avg_adr["avg_adr"])
plt.show()

# %% [markdown]
# City hotels are making more money than resort hotels because their typical daily rate is higher and their booking volume is higher.

# %% [markdown]
# # **Top ten countries from which the booking has been done.**

# %%
country_name,pct_of_country = calc_count(df_not_canceled["country"],limit=10)
sns.barplot(x=country_name,y=pct_of_country)
plt.show()

# %% [markdown]
# The majority of reservations are made using the PR area code.
# The second-highest volume of reservations are made using the country codes GBR, FRA, ESP, and DEU.

# %% [markdown]
# # **Booking hotels in different years.**

# %%
plt.subplots(figsize=(8,6))
sns.countplot(x='arrival_date_year', hue='hotel', data=df_not_canceled);
plt.title("Booking hotels in different years.")
plt.xlabel("years")
plt.ylabel("Hotel booking count")
plt.show()

# %% [markdown]
# The majority of bookings were made in 2016.

# %% [markdown]
# ## **Percentage of hotel booking each year.**

# %% [markdown]
# # **Which month of the year is the hotel the busiest?**

# %%
plt.figure(figsize=(14,7))
month_hotel_order = ["January","February","March","April","May","June","July","August","September","October","November","December"]

sns.countplot(data=df_not_canceled,x='arrival_date_month', order = month_hotel_order, hue = "hotel")

plt.title('Best time for bookings')
plt.xlabel('Months')
plt.ylabel('Reservation Count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# August is the month with the most hotel bookings, followed by July and May.
# The two months with the fewest bookings were January and December.

# %% [markdown]
# # **The ideal time of year to get best rate**

# %%
plt.figure(figsize=(14,5))
sns.lineplot(x = "arrival_date_month", y="adr", hue="hotel", data=df,
             hue_order = ["City Hotel", "Resort Hotel"],palette= 'Set1',linewidth = 2)

plt.title("Monthwise average daily rate", weight = 'bold')
plt.xlabel("Arrival Month")
plt.ylabel("ADR")
plt.show()

# %% [markdown]
# July and August see the highest ADR levels. This can be deduced because the ADR is significant in those months due to the high demand, as seen in the previous chart.
# Customers favour city hotels over resort hotels during those summer months.
#
# ADR for city hotels is essentially constant month to month, but is relatively low in December and January.

# %% [markdown]
# # **Which month has the highest cancellation rate**

# %%
plt.style.use("seaborn")
plt.figure(figsize = (14,7))
month_order = ["January","February","March","April","May","June","July","August","September","October","November","December"]

sns.countplot(x="arrival_date_month",order = month_order, hue = "is_canceled",data = df)
plt.xlabel("Months")
plt.ylabel("Hotel count")
plt.show()
# Out:
# <ipython-input-36-8a21b5e865de>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
df["meal"].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
plt.style.use("ggplot")
sns.countplot(x="meal",hue = 'hotel',data = df_not_canceled)
plt.show()

# %% [markdown]
# The majority of people favour BB-style meals.

# %%
sns.countplot(x="deposit_type",data = df)
plt.xlabel("Deposit type")
plt.show()

# %% [markdown]
# More deposits are made than with alternative choices.

# %%
df["customer_type"].unique()
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
plt.style.use("seaborn-whitegrid")
plt.figure(figsize=(5,7))
sns.countplot(x="customer_type",hue="is_canceled",data=df)
plt.xlabel("Type of customers")
plt.show()
# Out:
# <ipython-input-41-6e5e08e2af27>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %% [markdown]
# The majority of clients are transient in nature.
#
# The majority of cancellations were also of the transient variety.

# %%
plt.figure(figsize=(5,7))
sns.boxplot(x="is_canceled",y="lead_time",data = df,linewidth = 2)
plt.show()

# %% [markdown]
# The majority of lead times in cases of cancelled requests are larger than 100 days.
#
# When it comes to cancelled inquiries, there are some exceptional outliers.

# %% [markdown]
# # **Analysis of customer types.**

# %%
sns.countplot(x="customer_type",data=df)
# Out:
# <Axes: xlabel='customer_type', ylabel='count'>

# %%
sns.countplot(x="customer_type",hue="is_repeated_guest", data=df)
# Out:
# <Axes: xlabel='customer_type', ylabel='count'>

# %% [markdown]
# Distribution according to hotel

# %%
plt.style.use("fivethirtyeight")
meal_count,pct_meal_count = calc_count(df["meal"])
sns.countplot(x = "meal",hue = "hotel",data = df)
plt.legend(loc ="upper right")
plt.show()

# %% [markdown]
# ### **Channel wise distribution**

# %%
plt.figure(figsize=(10,5))
groupby_dc = df.groupby("distribution_channel")
median_lead_time = groupby_dc["lead_time"].median().reset_index().rename(columns = {"lead_time":"median_lead_time"})
sns.barplot(x = median_lead_time["distribution_channel"],y = median_lead_time["median_lead_time"])
plt.show()

# %% [markdown]
# Lead time is lengthy for travel agencies or travel operators.

# %%
plt.figure(figsize=(10,5))
avg_cancelation_count = groupby_dc["is_canceled"].mean().reset_index().rename(columns = {"is_canceled":"avg_cancel"})
sns.barplot(x = avg_cancelation_count["distribution_channel"],y = avg_cancelation_count["avg_cancel"])
plt.xlabel("Distribution Chanel")
plt.ylabel("Cancellation Average")
plt.show()

# %% [markdown]
# The rate of cancellation for undefined booking channels is high.

# %%
plt.figure(figsize=(10,5))
avg_adr_count = groupby_dc["adr"].mean().reset_index().rename(columns = {"adr":"avg_adr"})
sns.barplot(x = avg_adr_count["distribution_channel"],y = avg_adr_count["avg_adr"])
plt.xlabel("Distribution Chanel")
plt.ylabel("Average ADR")
plt.show()

# %% [markdown]
# For the GDS style of distribution channel, the average ADR is high.

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'all_night', 'kids',
#        'num_customers'],
#       dtype='object')

# %% [markdown]
# ## **What if you wished to forecast the likelihood that a hotel would get an unusually high number of special requests?**

# %%
sns.boxplot(x= "market_segment",y = "total_of_special_requests",hue = "market_segment",data = df,linewidth =1)
fig= plt.gcf()
fig.set_size_inches(15,10)

plt.show()

# %% [markdown]
# Hotels are receiving extremely high demand for almost all market segments.

# %% [markdown]
# ## **Analysis of special requests**

# %%
sns.countplot(x="total_of_special_requests",hue ="hotel",data = df,linewidth= 1)
fig= plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
plt.style.use('ggplot')
sns.barplot(x="kids",y="total_of_special_requests",data = df,linewidth= 1)
fig= plt.gcf()
fig.set_size_inches(10,7)
plt.show()

# %% [markdown]
# If the customers have children with numbers one, two, three, and ten, the number of special requests is high.

# %%
plt.style.use('seaborn')
sns.barplot(x="adults",y="total_of_special_requests",data = df_not_canceled,linewidth= 1)
fig= plt.gcf()
fig.set_size_inches(10,7)
plt.show()
# Out:
# <ipython-input-53-6b975fb5f5ce>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# Customers who reserve hotels for two, three, or four people frequently request special accommodations.
#
# When customers reserve hotels for one person, there are fewer special requests.

# %% [markdown]
# When there are between 2 and 4 adult customers, the average special request is high.

# %% [markdown]
# ## **Analysis of evenings spent in hotels.**

# %%
sns.countplot(x="all_night",hue="hotel",data = df_not_canceled)
fig= plt.gcf()
fig.set_size_inches(16,8)
plt.show()

# %% [markdown]
# Most customers who reserve hotels in cities favour stays of 1 to 4 days.
#
# Most customers who reserve resort lodgings prefer stays of one to seven days, most frequently one, two, or three days.

# %%
month_order = ["January","February","March","April","May","June","July","August","September","October","November","December"]

sns.barplot(y="all_night",x="arrival_date_month",order=month_order,data = df_not_canceled)
fig= plt.gcf()
fig.set_size_inches(16,8)
plt.show()

# %% [markdown]
# In comparison to the other months, July and August have a higher percentage of overnight stays.

# %%
sns.barplot(y="all_night",x="arrival_date_year",hue = "hotel",data = df_not_canceled)
fig= plt.gcf()
fig.set_size_inches(10,7)
plt.show()

# %% [markdown]
# ## **Analysis of Hotel Cancellations**

# %%
df_is_canceled = df[(df["is_canceled"]==1)]
defined_chanel = df[df["distribution_channel"] != "Undefined"]
defined_chanel["distribution_channel"].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'GDS'], dtype=object)

# %%
distribution_channel_values, pct_distribution_channel_value = calc_count(defined_chanel["distribution_channel"])
sns.barplot(x=distribution_channel_values,y=pct_distribution_channel_value)
plt.xlabel("Distribution Chanels")
plt.ylabel("Percent Of cancellation")
plt.show()

# %% [markdown]
# The majority of cancellations were made through the TA/TO channel.

# %% [markdown]
# Request cancellation with various delay times and waiting days.

# %%
waiting_bookings = df[df['days_in_waiting_list'] !=0]  

fig, axes = plt.subplots(1, 2, figsize=(18, 8))
sns.kdeplot(ax=axes[0],x = 'days_in_waiting_list', hue = 'is_canceled' , data = waiting_bookings)
sns.kdeplot(ax = axes[1], x = df['lead_time'], hue = df['is_canceled'])
plt.show()

# %% [markdown]
# While it is evident that the majority of revoked reservations have waiting periods under 150 days, the majority of confirmed reservations also do. This demonstrates that the waiting time has no bearing on booking cancellations.
#
# Additionally, because the curves for cancellation and not-cancellation are similar for advance time as well, lead time has no impact on cancellation of bookings.

# %%
d1 = pd.DataFrame((groupby_dc['is_canceled'].sum()/groupby_dc.size())*100).drop(index = 'Undefined').rename(columns = {0: 'Cancel_%'})
plt.figure(figsize = (10,5))
sns.barplot(x = d1.index, y = d1['Cancel_%'])
plt.show()

# %%
country_wise_cancel,pct_country_wise_cancel = calc_count(df_is_canceled["country"],limit = 10)
sns.barplot(x=country_wise_cancel,y=pct_country_wise_cancel)
plt.show()

# %% [markdown]
# # **What is the ideal duration of stay to obtain the best daily rate?**

# %%
plt.figure(figsize = (14,8))
sns.scatterplot(y = 'adr', x = 'all_night', data = df_not_canceled)
plt.show()

# %% [markdown]
#   Customers can get the best rate for booking when they remain in hotels for more than 20 days.

# %% [markdown]
# # **Comparison of prices and demand for parking spaces at various types of hotels.**

# %%
sns.barplot(y = "adr",x= "required_car_parking_spaces",hue = "hotel",data = df)
plt.show()

# %% [markdown]
# The desire is highest when two parking spaces are needed.
#
# Additionally, the adr is considerable if there are only two parking spaces.
#
# Compared to resort hotels, city hotels have a greater ADR.

# %% [markdown]
# # **Various client types, such as Single, Couple, and Family, and their hotel needs.**

# %%
single = df_not_canceled[(df_not_canceled['adults'] == 1) & (df_not_canceled["kids"] == 0)]
couple = df_not_canceled[(df_not_canceled['adults'] == 2) & (df_not_canceled["kids"] == 0)]
family = df_not_canceled[(df_not_canceled['adults'] >= 2) & (df_not_canceled["kids"] >= 1)]

fig,axes = plt.subplots(1,3,figsize =(15,6))
sns.countplot(ax = axes[0],x="hotel",hue="hotel",data = single)
sns.countplot(ax = axes[1],x="hotel",hue="hotel",data = couple)
sns.countplot(ax = axes[2],x="hotel",hue="hotel",data = family)
axes[0].set_title("For single type customer")
axes[1].set_title("For couple type customer")
axes[2].set_title("For family type customer")

plt.show()

# %% [markdown]
# # **Various customer types, such as Single, Couple, and Family, and their frequency of arrival in different months.**

# %%
reindex = ['January', 'February','March','April','May','June','July','August','September','October','November','December']

fig, ax = plt.subplots(figsize=(12, 8))

for type in ['single', 'couple', 'family']:
  df = eval(type).groupby(['arrival_date_month']).size().reset_index().rename(columns = {0:'arrival_num'})
  df['arrival_date_month'] = pd.Categorical(df['arrival_date_month'],categories=reindex,ordered=True)
  sns.lineplot(data=df, x= 'arrival_date_month', y='arrival_num', label=type, ax=ax)
plt.title("Customer type and their number of arrival in various months.") 
plt.xlabel("Months") 
plt.ylabel("Number of various customer type")
plt.grid(True)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# Most hotel reservations are made by couples (two people). They favour the months of July and August.
#
# Customers who are single tend to favour March and October the most.
#
# Families (defined as at least two people and at least one child) favour the months of July and August the most.
